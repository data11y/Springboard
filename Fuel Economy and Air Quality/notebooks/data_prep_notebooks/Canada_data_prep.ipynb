# %%
import pandas as pd
import numpy as np
import os
import glob

# %%
canada_air_data_dir = "../data/raw_data/Canada/air/"

# %% [markdown]
# ## Canada air pollutants data prep

# %% [markdown]
# ### Pollutants in consideration
#
# PM2.5: Airborne Particulate Matter measuring 2.5 micrometers or smaller<br>
# PM10: Airborne Particulate Matter measuring < 10 micrometers > 2.5 micrometers<br>
# NO2: Nitrogen Dioxide<br>
# SO2: Sulphur Dioxide<br>
# CO: Carbon Monoxide<br>
# O3: Ozone<br>

# %%
def prepCAair(pollutant, groupby=True):
    try:
        df_00_16 = pd.read_csv(os.path.join(canada_air_data_dir, pollutant.upper()+'_00_16.csv'), parse_dates=[0], usecols=[0, 5])
        df_17 = pd.read_csv(os.path.join(canada_air_data_dir, pollutant.upper()+'_17.csv'), parse_dates=[0], usecols=[0, 7])
        
    except FileNotFoundError:
        print('File not found. Accepted values {o3, co, no2, so2, pm25, pm10} case-indifferent')
        
    df = df_00_16.append(df_17, ignore_index=True)
    assert ['DATE_PST', 'RAW_VALUE'] == df.columns.values.tolist()
    
    df.rename(columns={'DATE_PST':'year', 'RAW_VALUE':pollutant.lower()+'_mean'}, inplace=True)
    df['year'] = df['year'].dt.year
    
    df = df[df.year < 2018]
    df = df[df[df.columns[1]] >= 0]
    if groupby:
        df_groupby = df.groupby('year').mean()
        return df_groupby
    return df

# %%
# Carbon Monoxide: CO
df_CA_air_CO = prepCAair('co')
df_CA_air_CO['co_units'] = 'ppm'
# Out:
#        co_mean co_units
# year
# 2000  0.464702      ppm
# 2001  0.429632      ppm
# 2002  0.431412      ppm

# %%
# Ozone: O3
df_CA_air_O3 = prepCAair('o3')
df_CA_air_O3['o3_units'] = 'ppb'
# Out:
#         o3_mean o3_units
# year
# 2000  14.981322      ppb
# 2001  16.440080      ppb
# 2002  16.304480      ppb

# %%
# Nitrogen DiOxide : NO2
df_CA_air_NO2 = prepCAair('no2')
df_CA_air_NO2['no2_units'] = 'ppb'
# Out:
#        no2_mean no2_units
# year
# 2000  13.304986       ppb
# 2001  12.443451       ppb
# 2002  12.235973       ppb

# %%
# Sulfur Dioxide: SO2
df_CA_air_SO2 = prepCAair('so2')
df_CA_air_SO2['so2_units'] = 'ppb'
# Out:
#       so2_mean so2_units
# year
# 2000  3.918739       ppb
# 2001  2.541681       ppb
# 2002  2.544733       ppb

# %%
# Particulate matter 2.5 micrometers and smaller in size
df_CA_air_PM25 = prepCAair('pm25')
df_CA_air_PM25['pm25_units'] = 'μg/m3'
# Out:
#       pm25_mean pm25_units
# year
# 2000   5.977311      ug/m3
# 2001   5.384297      ug/m3
# 2002   5.973789      ug/m3

# %%
# Particulate matter 10 micrometers and smaller
df_CA_air_PM10 = prepCAair('pm10')
df_CA_air_PM10['pm10_units'] = 'μg/m3'
# Out:
#       pm10_mean pm10_units
# year
# 2000  13.731744      ug/m3
# 2001  13.258304      ug/m3
# 2002  14.189306      ug/m3

# %%
df_CA_air = pd.concat([df_CA_air_CO, df_CA_air_O3, df_CA_air_NO2, df_CA_air_SO2, df_CA_air_PM25, df_CA_air_PM10], axis=1)
df_CA_air.head()
# Out:
#        co_mean co_units    o3_mean o3_units   no2_mean no2_units  so2_mean  \
# year
# 2000  0.464702      ppm  14.981322      ppb  13.304986       ppb  3.918739
# 2001  0.429632      ppm  16.440080      ppb  12.443451       ppb  2.541681
# 2002  0.431412      ppm  16.304480      ppb  12.235973       ppb  2.544733
# 2003  0.421084      ppm  17.127153      ppb  11.975094       ppb  3.047193
# 2004  0.424777      ppm  16.083696      ppb  11.233853       ppb  2.629271
#
#      so2_units  pm25_mean pm25_units  pm10_mean pm10_units
# year
# 2000       ppb   5.977311      ug/m3  13.731744      ug/m3
# 2001       ppb   5.384297      ug/m3  13.258304      ug/m3
# 2002       ppb   5.973789      ug/m3  14.189306      ug/m3
# 2003       ppb   6.284330      ug/m3  14.939431      ug/m3
# 2004       ppb   6.001286      ug/m3  14.737286      ug/m3

# %%
df_CA_air.to_csv("../data/transformed_data/Canada/df_ca_air.csv")

# %% [markdown]
# ## Canada fuel economy data prep

# %%
canada_fuel_data_dir = "../data/raw_data/Canada/fuel/"

# %%
CA_fuel_csv_glob = glob.glob(os.path.join(canada_fuel_data_dir, "*.csv"))

# %%
df_CA_fuel = pd.concat((pd.read_csv(f) for f in CA_fuel_csv_glob), ignore_index=True)
df_CA_fuel.head()
# Out:
#    YEAR   MAKE       MODEL VEHICLE CLASS  ENGINE SIZE (L)  CYLINDERS  \
# 0  2015  ACURA         ILX       COMPACT              2.0          4
# 1  2015  ACURA         ILX       COMPACT              2.4          4
# 2  2015  ACURA  ILX HYBRID       COMPACT              1.5          4
# 3  2015  ACURA  MDX SH-AWD   SUV - SMALL              3.5          6
# 4  2015  ACURA     RDX AWD   SUV - SMALL              3.5          6
#
#   TRANSMISSION FUEL TYPE  CITY (L/100 km)  HWY (L/100 km)  COMB (L/100 km)  \
# 0          AS5         Z              9.7             6.7              8.3
# 1           M6         Z             10.8             7.4              9.3
# 2          AV7         Z              6.0             6.1              6.1
# 3          AS6         Z             12.7             9.1             11.1
# 4          AS6         Z             12.1             8.7             10.6
#
#    COMB (mpg)  CO2 EMISSIONS  (g/km)  CO2 RATING  SMOG RATING  \
# 0          34                  191.0         NaN          NaN
# 1          30                  214.0         NaN          NaN
# 2          46                  140.0         NaN          NaN
# 3          25                  255.0         NaN          NaN
# 4          27                  244.0         NaN          NaN
#
#    CO2 EMISSIONS (g/km)
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN

# %%
df_CA_fuel.columns = df_CA_fuel.columns.str.lower()
df_CA_fuel.columns = df_CA_fuel.columns.str.replace("\s+\(", "(" )

# %%
df_CA_fuel.head()
# Out:
#    year   make       model vehicle class  engine size(l)  cylinders  \
# 0  2015  ACURA         ILX       COMPACT             2.0          4
# 1  2015  ACURA         ILX       COMPACT             2.4          4
# 2  2015  ACURA  ILX HYBRID       COMPACT             1.5          4
# 3  2015  ACURA  MDX SH-AWD   SUV - SMALL             3.5          6
# 4  2015  ACURA     RDX AWD   SUV - SMALL             3.5          6
#
#   transmission fuel type  city(l/100 km)  hwy(l/100 km)  comb(l/100 km)  \
# 0          AS5         Z             9.7            6.7             8.3
# 1           M6         Z            10.8            7.4             9.3
# 2          AV7         Z             6.0            6.1             6.1
# 3          AS6         Z            12.7            9.1            11.1
# 4          AS6         Z            12.1            8.7            10.6
#
#    comb(mpg)  co2 emissions(g/km)  co2 rating  smog rating  \
# 0         34                191.0         NaN          NaN
# 1         30                214.0         NaN          NaN
# 2         46                140.0         NaN          NaN
# 3         25                255.0         NaN          NaN
# 4         27                244.0         NaN          NaN
#
#    co2 emissions(g/km)
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN

# %%
# After renaming columns, we now have 2 duplicates

# Since these are from different datasets, it doesnt look like there is a row where both of these values are missing
(df_CA_fuel['co2 emissions(g/km)'].isna().sum(axis=1) > 1).sum()
# Out:
# 0

# %%
co2_emissions = df_CA_fuel['co2 emissions(g/km)'].sum(axis=1)
df_CA_fuel.drop('co2 emissions(g/km)', axis=1, inplace=True)
df_CA_fuel['co2 emissions(g/km)'] = co2_emissions
df_CA_fuel.head()
# Out:
#    year   make       model vehicle class  engine size(l)  cylinders  \
# 0  2015  ACURA         ILX       COMPACT             2.0          4
# 1  2015  ACURA         ILX       COMPACT             2.4          4
# 2  2015  ACURA  ILX HYBRID       COMPACT             1.5          4
# 3  2015  ACURA  MDX SH-AWD   SUV - SMALL             3.5          6
# 4  2015  ACURA     RDX AWD   SUV - SMALL             3.5          6
#
#   transmission fuel type  city(l/100 km)  hwy(l/100 km)  comb(l/100 km)  \
# 0          AS5         Z             9.7            6.7             8.3
# 1           M6         Z            10.8            7.4             9.3
# 2          AV7         Z             6.0            6.1             6.1
# 3          AS6         Z            12.7            9.1            11.1
# 4          AS6         Z            12.1            8.7            10.6
#
#    comb(mpg)  co2 rating  smog rating  co2 emissions(g/km)
# 0         34         NaN          NaN                191.0
# 1         30         NaN          NaN                214.0
# 2         46         NaN          NaN                140.0
# 3         25         NaN          NaN                255.0
# 4         27         NaN          NaN                244.0

# %%
transmission_decode_dict = {
    'A':'Automatic', 
    'AM':'Automated manual', 
    'AS':'Automatic with select shift',
    'AV':'Continuously variable',
    'M':'Manual'
}

fuel_type_decode_dict = {
    'X':'Regular',
    'Z':'Premium',
    'D':'Diesel',
    'E':'Ethanol (E85)',
    'N': 'Natural gas'    
}

# %%
df_CA_fuel['num_gears'] = df_CA_fuel.transmission.str.extract("(\d+)")
df_CA_fuel.transmission = df_CA_fuel.transmission.str.extract("([A-Z]+)")
df_CA_fuel.transmission = df_CA_fuel.transmission.map(transmission_decode_dict)
df_CA_fuel['fuel type'] = df_CA_fuel['fuel type'].map(fuel_type_decode_dict)

# %%
# CVT transmission is an diffferent approach to varying ratio gear sets, 
#    with a ratio pulley system most commonly used instead
# A gif explaining how it works: https://i.imgur.com/AmGPVy9.gifv

df_CA_fuel[df_CA_fuel.num_gears.isna()].transmission.value_counts()
# Out:
# Continuously variable    606
# Name: transmission, dtype: int64

# %%
df_CA_fuel.num_gears.fillna(0,inplace=True)
df_CA_fuel.drop(['co2 rating', 'smog rating'], axis=1, inplace=True)
df_CA_fuel.columns = df_CA_fuel.columns.str.replace("0 ", "")
df_CA_fuel.columns = df_CA_fuel.columns.str.replace(" ", "_")

# %%
df_CA_fuel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17553 entries, 0 to 17552
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   year                 17553 non-null  int64
#  1   make                 17553 non-null  object
#  2   model                17553 non-null  object
#  3   vehicle_class        17553 non-null  object
#  4   engine_size(l)       17553 non-null  float64
#  5   cylinders            17553 non-null  int64
#  6   transmission         17553 non-null  object
#  7   fuel_type            17553 non-null  object
#  8   city(l/10km)         17553 non-null  float64
#  9   hwy(l/10km)          17553 non-null  float64
#  10  comb(l/10km)         17553 non-null  float64
#  11  comb(mpg)            17553 non-null  int64
#  12  co2_emissions(g/km)  17553 non-null  float64
#  13  num_gears            17553 non-null  object
# dtypes: float64(5), int64(3), object(6)
# memory usage: 1.9+ MB

# %%
df_CA_fuel.describe()
# Out:
#                year  engine_size(l)   cylinders  city(l/10km)   hwy(l/10km)  \
# count  17553.000000    17553.000000  17553.0000  17553.000000  17553.000000
# mean    2009.168404        3.413046      5.9105     12.852561      8.847018
# std        4.972865        1.325078      1.7914      3.524094      2.302029
# min     2000.000000        0.800000      2.0000      3.500000      3.200000
# 25%     2005.000000        2.400000      4.0000     10.500000      7.300000
# 50%     2009.000000        3.300000      6.0000     12.300000      8.300000
# 75%     2013.000000        4.300000      8.0000     14.800000     10.200000
# max     2017.000000        8.400000     16.0000     30.600000     20.600000
#
#        comb(l/10km)     comb(mpg)  co2_emissions(g/km)
# count  17553.000000  17553.000000         17553.000000
# mean      11.051342     27.351051           248.701589
# std        2.942049      7.354517            58.818511
# min        3.600000     11.000000            83.000000
# 25%        9.100000     22.000000           208.000000
# 50%       10.500000     27.000000           242.000000
# 75%       12.800000     31.000000           285.000000
# max       26.100000     78.000000           570.000000

# %%
df_CA_fuel.head()
# Out:
#    year   make       model vehicle_class  engine_size(l)  cylinders  \
# 0  2015  ACURA         ILX       COMPACT             2.0          4
# 1  2015  ACURA         ILX       COMPACT             2.4          4
# 2  2015  ACURA  ILX HYBRID       COMPACT             1.5          4
# 3  2015  ACURA  MDX SH-AWD   SUV - SMALL             3.5          6
# 4  2015  ACURA     RDX AWD   SUV - SMALL             3.5          6
#
#                   transmission fuel_type  city(l/10km)  hwy(l/10km)  \
# 0  Automatic with select shift   Premium           9.7          6.7
# 1                       Manual   Premium          10.8          7.4
# 2        Continuously variable   Premium           6.0          6.1
# 3  Automatic with select shift   Premium          12.7          9.1
# 4  Automatic with select shift   Premium          12.1          8.7
#
#    comb(l/10km)  comb(mpg)  co2_emissions(g/km) num_gears
# 0           8.3         34                191.0         5
# 1           9.3         30                214.0         6
# 2           6.1         46                140.0         7
# 3          11.1         25                255.0         6
# 4          10.6         27                244.0         6

# %%
df_CA_fuel.to_csv('../data/transformed_data/Canada/df_CA_fuel.csv',index=False)

# %%
df_CA_fuel.groupby(['year','vehicle_class', 'engine_size(l)', 'cylinders']).mean()
# Out:
#                                                city(l/10km)  hwy(l/10km)  \
# year vehicle_class   engine_size(l) cylinders
# 2000 COMPACT         1.5            4              8.000000     5.800000
#                      1.6            4              8.875000     6.700000
#                      1.8            4              9.913333     7.066667
#                      1.9            4              7.512500     5.125000
#                      2.0            4              9.884211     6.921053
# ...                                                     ...          ...
# 2017 TWO-SEATER      6.5            12            23.250000    13.800000
#                      8.4            10            19.900000    12.600000
#      VAN - PASSENGER 3.5            6             16.200000    12.800000
#                      3.7            6             19.850000    15.750000
#                      6.0            8             22.050000    14.850000
#
#                                                comb(l/10km)  comb(mpg)  \
# year vehicle_class   engine_size(l) cylinders
# 2000 COMPACT         1.5            4              7.000000  40.750000
#                      1.6            4              7.900000  35.750000
#                      1.8            4              8.633333  33.133333
#                      1.9            4              6.462500  44.750000
#                      2.0            4              8.547368  33.157895
# ...                                                     ...        ...
# 2017 TWO-SEATER      6.5            12            19.000000  14.750000
#                      8.4            10            16.600000  17.000000
#      VAN - PASSENGER 3.5            6             14.600000  19.000000
#                      3.7            6             18.000000  16.500000
#                      6.0            8             18.800000  15.000000
#
#                                                co2_emissions(g/km)
# year vehicle_class   engine_size(l) cylinders
# 2000 COMPACT         1.5            4                   161.000000
#                      1.6            4                   181.750000
#                      1.8            4                   198.666667
#                      1.9            4                   159.625000
#                      2.0            4                   196.631579
# ...                                                            ...
# 2017 TWO-SEATER      6.5            12                  447.000000
#                      8.4            10                  387.000000
#      VAN - PASSENGER 3.5            6                   344.000000
#                      3.7            6                   348.500000
#                      6.0            8                   441.500000
#
# [3558 rows x 5 columns]
